# %%
from google.colab import drive

# %%
cd /content/drive/MyDrive/머신러닝 딥러닝/BC-TCGA
# Out:
# /content/drive/MyDrive/머신러닝 딥러닝/BC-TCGA

# %%
import pandas as pd
import numpy as np

# %%
ls
# Out:
# BC-TCGA-Normal.txt  BC-TCGA-Tumor.txt

# %%
normal_df = pd.read_table("BC-TCGA-Normal.txt")
tumor_df = pd.read_table("BC-TCGA-Tumor.txt")

# %%
normal_df.head()
# Out:
#   Hybridization REF  TCGA-BH-A0AY-11A-23R-A089-07  \
# 0             ELMO2                      0.204333
# 1           CREB3L1                     -0.242000
# 2             RPS11                      0.591875
# 3             PNMA1                      0.538500
# 4              MMP2                      0.707667
#
#    TCGA-A7-A0DB-11A-33R-A089-07  TCGA-BH-A0HK-11A-11R-A089-07  \
# 0                      0.869417                       0.06450
# 1                      0.878250                       0.27350
# 2                     -0.024625                       0.47775
# 3                      0.819500                       0.29025
# 4                      1.932333                       0.99000
#
#    TCGA-BH-A0BM-11A-12R-A089-07  TCGA-BH-A0B3-11B-21R-A089-07  \
# 0                     -0.186250                      0.063250
# 1                     -0.814500                     -0.746500
# 2                      0.701875                      0.628750
# ...

# %%
tumor_df.head()
# Out:
#   Hybridization REF  TCGA-AO-A03P-01A-11R-A00Z-07  \
# 0             ELMO2                      1.219417
# 1           CREB3L1                     -0.152250
# 2             RPS11                      2.193375
# 3             PNMA1                     -0.218750
# 4              MMP2                     -0.148667
#
#    TCGA-A8-A06T-01A-11R-A00Z-07  TCGA-A8-A07F-01A-11R-A00Z-07  \
# 0                      0.430333                      0.439833
# 1                      0.444500                      1.882250
# 2                     -0.100625                      0.055625
# 3                     -0.167500                     -0.026000
# 4                     -0.206000                      0.970167
#
#    TCGA-A8-A081-01A-11R-A00Z-07  TCGA-A8-A08C-01A-11R-A00Z-07  \
# 0                      1.242667                     -0.228333
# 1                      1.781000                      0.533500
# 2                      0.269500                      0.722375
# ...

# %%
print(tumor_df.shape)
# Out:
# (17814, 530)

# %%
print(normal_df.shape)
# Out:
# (17814, 62)

# %%
tumor_df_T = tumor_df.T
normal_df_T = normal_df.T

# %%
tumor_df_T.head()
# Out:
#                                  0        1         2        3         4      \
# Hybridization REF                ELMO2  CREB3L1     RPS11    PNMA1      MMP2
# TCGA-AO-A03P-01A-11R-A00Z-07  1.219417 -0.15225  2.193375 -0.21875 -0.148667
# TCGA-A8-A06T-01A-11R-A00Z-07  0.430333   0.4445 -0.100625  -0.1675    -0.206
# TCGA-A8-A07F-01A-11R-A00Z-07  0.439833  1.88225  0.055625   -0.026  0.970167
# TCGA-A8-A081-01A-11R-A00Z-07  1.242667    1.781    0.2695  0.14975 -1.073167
#
#                                  5         6        7         8       9      \
# TCGA-A8-A081-01A-11R-A00Z-07 -2.74075  0.379667 -0.23675   -1.7785   0.761
# TCGA-A8-A08C-01A-11R-A00Z-07   -1.848    -0.554  0.09875    -1.851  0.7265
#
# ...

# %%
normal_df_T.rename(columns=normal_df_T.iloc[0], inplace=True)
normal_df_T = normal_df_T.drop(normal_df_T.index[0])
normal_df_T.head()
# Out:
#                                  ELMO2  CREB3L1     RPS11    PNMA1      MMP2  \
# TCGA-BH-A0AY-11A-23R-A089-07  0.204333   -0.242  0.591875   0.5385  0.707667
# TCGA-A7-A0DB-11A-33R-A089-07  0.869417  0.87825 -0.024625   0.8195  1.932333
# TCGA-BH-A0HK-11A-11R-A089-07    0.0645   0.2735   0.47775  0.29025      0.99
# TCGA-BH-A0BM-11A-12R-A089-07  -0.18625  -0.8145  0.701875   0.2335 -1.705667
# TCGA-BH-A0B3-11B-21R-A089-07   0.06325  -0.7465   0.62875  0.44275  0.700167
#
#                              C10orf90      ZHX3   ERCC5     GPR98  RXFP3  ...  \
# TCGA-BH-A0AY-11A-23R-A089-07   0.2755 -0.117167  0.5185 -0.018375 -0.059  ...
# TCGA-A7-A0DB-11A-33R-A089-07  -0.4175  0.570833   0.501 -2.131375  0.595  ...
# TCGA-BH-A0HK-11A-11R-A089-07 -0.10875  0.204333   0.035 -0.524625  0.011  ...
# TCGA-BH-A0BM-11A-12R-A089-07  0.93925 -0.468167  0.5755  0.112875 -0.118  ...
# TCGA-BH-A0B3-11B-21R-A089-07  0.10675 -0.376667  0.4775    0.1795 -0.344  ...
#
# ...

# %%
#레이블 추가하기: tumor=1, normal=0

tumor_df_T['label'] = 1
normal_df_T['label'] = 0

# %%
normal_df_T.columns, tumor_df_T.columns
# Out:
# (Index(['ELMO2', 'CREB3L1', 'RPS11', 'PNMA1', 'MMP2', 'C10orf90', 'ZHX3',
#         'ERCC5', 'GPR98', 'RXFP3',
#         ...
#         'GRIP2', 'GPLD1', 'RAB8A', 'RXFP2', 'PIK3IP1', 'SLC39A6', 'SNRPD2',
#         'AQP7', 'CTSC', 'label'],
#        dtype='object', length=17815),
#  Index(['ELMO2', 'CREB3L1', 'RPS11', 'PNMA1', 'MMP2', 'C10orf90', 'ZHX3',
#         'ERCC5', 'GPR98', 'RXFP3',
#         ...
#         'GRIP2', 'GPLD1', 'RAB8A', 'RXFP2', 'PIK3IP1', 'SLC39A6', 'SNRPD2',
#         'AQP7', 'CTSC', 'label'],
#        dtype='object', length=17815))

# %%
normal_df_T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, TCGA-BH-A0AY-11A-23R-A089-07 to TCGA-BH-A1EO-11A-31R-A137-07
# Columns: 17815 entries, ELMO2 to label
# dtypes: int64(1), object(17814)
# memory usage: 8.3+ MB

# %%
# binary classification 수행하기
#성능좋게
#도움안되는 피처를 줄여나가기
#

# %%
#두 데이터셋 합치기
df = pd.concat([normal_df_T, tumor_df_T])
df.head()
# Out:
#                                  ELMO2  CREB3L1     RPS11    PNMA1      MMP2  \
# TCGA-BH-A0AY-11A-23R-A089-07  0.204333   -0.242  0.591875   0.5385  0.707667
# TCGA-A7-A0DB-11A-33R-A089-07  0.869417  0.87825 -0.024625   0.8195  1.932333
# TCGA-BH-A0HK-11A-11R-A089-07    0.0645   0.2735   0.47775  0.29025      0.99
# TCGA-BH-A0BM-11A-12R-A089-07  -0.18625  -0.8145  0.701875   0.2335 -1.705667
# TCGA-BH-A0B3-11B-21R-A089-07   0.06325  -0.7465   0.62875  0.44275  0.700167
#
#                              C10orf90      ZHX3   ERCC5     GPR98  RXFP3  ...  \
# TCGA-BH-A0AY-11A-23R-A089-07   0.2755 -0.117167  0.5185 -0.018375 -0.059  ...
# TCGA-A7-A0DB-11A-33R-A089-07  -0.4175  0.570833   0.501 -2.131375  0.595  ...
# TCGA-BH-A0HK-11A-11R-A089-07 -0.10875  0.204333   0.035 -0.524625  0.011  ...
# TCGA-BH-A0BM-11A-12R-A089-07  0.93925 -0.468167  0.5755  0.112875 -0.118  ...
# TCGA-BH-A0B3-11B-21R-A089-07  0.10675 -0.376667  0.4775    0.1795 -0.344  ...
#
# ...

# %%
#데이터행 셔플
import sklearn
df = sklearn.utils.shuffle(df)

# %%
df.head()
# Out:
#                                  ELMO2 CREB3L1     RPS11    PNMA1      MMP2  \
# TCGA-AO-A12H-01A-11R-A115-07  0.610333   1.755  0.403875  0.50325 -0.142167
# TCGA-A2-A04U-01A-11R-A115-07  0.055917   0.245  0.337125 -0.41175 -0.550667
# TCGA-AR-A1AS-01A-11R-A12P-07  0.785583  1.1935  0.314375   0.4135  1.010333
# TCGA-AO-A0J4-01A-11R-A034-07  0.232667  0.0055   0.74575    0.294  0.168833
# TCGA-E2-A15D-01A-11R-A115-07  0.286917    1.11   0.20975 -0.01525     0.813
#
#                              C10orf90      ZHX3    ERCC5     GPR98   RXFP3  \
# TCGA-AO-A12H-01A-11R-A115-07  -2.1695  0.136833  0.92325 -1.794625   0.243
# TCGA-A2-A04U-01A-11R-A115-07  0.18475     -0.13   -0.753  -1.76175  0.8385
# TCGA-AR-A1AS-01A-11R-A12P-07 -1.56675 -0.032833   0.2005 -2.331125   0.357
# TCGA-AO-A0J4-01A-11R-A034-07 -1.59375 -0.757667 -0.22975  -1.75125    0.66
# TCGA-E2-A15D-01A-11R-A115-07   -1.899   -0.4705  0.13575    0.2255  0.4495
#
# ...

# %%
df.to_csv("cancer_calssification.csv",index=False)
